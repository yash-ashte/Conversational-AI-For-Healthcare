# %%
from sklearn.datasets import load_iris
from model import Data_Model

# %%
data_model = Data_Model('iris_dataset.csv', 'iris_xgboost_model.pkl')

# %%
print(data_model.get_feature_names())
# Out:
# ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']

# %%
print(data_model.get_flower_types())
# Out:
# ['setosa', 'versicolor', 'virginica']

# %%
print(data_model.data_header())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
print(data_model.describe_data())
# Out:
#        sepal length (cm)  sepal width (cm)  petal length (cm)  \
# count         150.000000        150.000000         150.000000
# mean            5.843333          3.057333           3.758000
# std             0.828066          0.435866           1.765298
# min             4.300000          2.000000           1.000000
# 25%             5.100000          2.800000           1.600000
# 50%             5.800000          3.000000           4.350000
# 75%             6.400000          3.300000           5.100000
# max             7.900000          4.400000           6.900000
#
#        petal width (cm)
# count        150.000000
# mean           1.199333
# std            0.762238
# min            0.100000
# 25%            0.300000
# 50%            1.300000
# 75%            1.800000
# max            2.500000

# %%
print(data_model.get_accuracy_score())
# Out:
# 1.0

# %%
print(data_model.get_classification_report())
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        50
#   versicolor       1.00      1.00      1.00        50
#    virginica       1.00      1.00      1.00        50
#
#     accuracy                           1.00       150
#    macro avg       1.00      1.00      1.00       150
# weighted avg       1.00      1.00      1.00       150

# %%
print(data_model.get_confusion_matrix())
# Out:
# [[50  0  0]
#  [ 0 50  0]
#  [ 0  0 50]]

# %%
print(data_model.predict(6.1, 2.8, 4.7, 1.2))
# Out:
# Predicted versicolor with 98.712% confidence

# %%
data_model.plot_descriptive("petal length (cm)", separate_species=True)

# %%
data_model.plot_descriptive("petal width (cm)", plot_type='boxplot')

# %%
print(data_model.predict(6.1, 2.8, 4.7, 1.2, feature_importance=True))
# Out:
# Predicted versicolor with 98.712% confidence
# Feature Importance SHAP values:
#   sepal length (cm): 0.2906035780906677
#   sepal width (cm): -0.32935675978660583
#   petal length (cm): 1.9585554599761963
#   petal width (cm): 0.5273882746696472

# %%
print(data_model.shap_feature_importance("versicolor"))
# Out:
# Shap Values for versicolor classification
#   sepal length (cm): 0.6713113784790039
#   sepal width (cm): 0.23347081243991852
#   petal length (cm): 1.7148152589797974
#   petal width (cm): 0.5791196823120117
